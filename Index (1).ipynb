# %% [markdown]
# # Welcome to Jupyter!

# %%
import requests
import json
import pandas as pd

# %%
query = """ query swaps{
  swaps(where:{transaction:"0x5ed0ee8ff25e0a368519ba10822d2f1d4261ca8cf3fe42b4f5806a515865d88f"})
    id
    timestamp
    amount0In
    amount1In
    amount0Out
    amount1Out
    sender
    to
    pair {
      token0 {
        id
        symbol
        totalLiquidity
        tradeVolumeUSD
        
      }
      token1 {
        id
        symbol
        totalLiquidity
        tradeVolumeUSD
      }
     }
    }
  }
  """

# %%
url = 'https://api.etherscan.io/api?module=contract&action=getabi&address=0xBB9bc244D798123fDe783fCc1C72d3Bb8C189413&apikey=I28EGN49B8ADEGC9SJZZJZQGBM9S1AVSKT'
r = requests.post(url, json={'query': query})
print(r.status_code)
# Out:
# 200

# %%
json_data = json.loads(r.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-58ec3ee02226> in <module>
#       1 json_data = json.loads(r.text)
# ----> 2 response.json
#
# NameError: name 'response' is not defined

# %%
df_data = json_data[‘data’][‘characters’][‘results’]
df = pd.DataFrame(df_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-66306d21d857> in <module>
# ----> 1 pd.json_normalize(r.text)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     271             # naive normalization, this is idempotent for flat records
#     272             # and potentially will inflate the data considerably for
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
# ...
